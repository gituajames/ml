# %%
import geopandas as gpd
import matplotlib

# %%
data = gpd.read_file('data/ke_rangeland.shp')

# %%
data.columns
# Out:
# Index(['RLID', 'RANGELAND', 'geometry'], dtype='object')

# %%
data.plot()
